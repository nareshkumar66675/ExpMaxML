# %%
from pandas import DataFrame, read_csv

import matplotlib.pyplot as plt
import pandas as pd #this is how I usually import pandas
import sys #only needed to determine Python version number
import matplotlib #only needed to determine Matplotlib version number

# Enable inline plotting
# %matplotlib inline

# %%
liverFilePath = r'C:\Users\kumar\Downloads\indian-liver-patient-records\indian_liver_patient.csv'
liverDF = pd.read_csv(liverFilePath)
liverDF
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65  Female              0.7               0.1                   187
# 1     62    Male             10.9               5.5                   699
# 2     62    Male              7.3               4.1                   490
# 3     58    Male              1.0               0.4                   182
# 4     72    Male              3.9               2.0                   195
# 5     46    Male              1.8               0.7                   208
# 6     26  Female              0.9               0.2                   154
# 7     29  Female              0.9               0.3                   202
# 8     17    Male              0.9               0.3                   202
# 9     55    Male              0.7               0.2                   290
# 10    57    Male              0.6               0.1                   210
# 11    72    Male              2.7               1.3                   260
# ...

# %%
bilAlDF = liverDF[['Total_Bilirubin','Albumin']]
Bil =

# %%
plt.scatter(bilAlDF.Total_Bilirubin,bilAlDF.Albumin)

# %%
bilAlDF.Albumin.plot()
